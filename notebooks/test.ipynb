# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# array([[345.41428, 364.95584, 347.26483, 288.80334, 422.52658, 429.24496,
#         311.02713]], dtype=float32)
# array([[345.41428, 364.95584, 347.26483, 288.80334, 422.52658, 429.24496,
#         311.02713]], dtype=float32)

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta

# Download the stock data for the last 30 days
today = datetime.today()
start_date = (today - timedelta(days=90)).strftime('%Y-%m-%d')
dataframe = yf.download("AAPL", start=start_date, end=today.strftime('%Y-%m-%d'))
display(dataframe)
# Filter the Close column from the dataframe
df = dataframe[['Close']]
input = scaler.fit_transform(df)
# Get the actual prices for the last 30 days
actual_prices = df[['Close']].values.tolist()

# Make predictions for the next 7 days using the last 30 days of actual prices
predictions = model.predict(input.reshape(1, 60, 1))
predictions = scaler.inverse_transform(predictions)
print(predictions)

# Create a range of dates to use as x-axis
dates = pd.date_range(start=start_date, end=today, freq='D')

# Plot the actual and predicted prices
plt.figure(figsize=(20, 5))
plt.ylim(100, 500)
plt.plot(dates[:len(actual_prices)], actual_prices, label='Actual Price')
plt.plot(dates[len(actual_prices): len(actual_prices) + len(predictions[0])], predictions[0], label='Predicted Price', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.title('Apple Stock Price')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Date
# 2022-11-09 00:00:00-05:00  138.500000  138.550003  134.589996  134.869995
# 2022-11-10 00:00:00-05:00  141.240005  146.869995  139.500000  146.869995
# 2022-11-11 00:00:00-05:00  145.820007  150.009995  144.369995  149.699997
# 2022-11-14 00:00:00-05:00  148.970001  150.279999  147.429993  148.279999
# 2022-11-15 00:00:00-05:00  152.220001  153.589996  148.559998  150.039993
# 2022-11-16 00:00:00-05:00  149.130005  149.869995  147.289993  148.789993
# 2022-11-17 00:00:00-05:00  146.429993  151.479996  146.149994  150.720001
# 2022-11-18 00:00:00-05:00  152.309998  152.699997  149.970001  151.289993
# 2022-11-21 00:00:00-05:00  150.160004  150.369995  147.720001  148.009995
# 2022-11-22 00:00:00-05:00  148.130005  150.419998  146.929993  150.179993
# 2022-11-23 00:00:00-05:00  149.449997  151.830002  149.339996  151.070007
# ...
